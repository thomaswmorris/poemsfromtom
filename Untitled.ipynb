# %%
import pandas as pd
import numpy as np

# %%
history = pd.read_csv('history.csv',index_col=0)

# %%
#history

# %%
#history.insert(3,'type',['daily' for dt in history['date']])
#history.insert(3,'date',[dt.split()[0] for dt in history['date time']])
#history.insert(4,'time',[dt.split()[1] for dt in history['date time']])
#history.drop(columns=['date time'],inplace=True)

history.to_csv('history.csv')

# %%
history
# Out:
#            poet                                 title   type        date  \
# #
# 0        milosz                               ACCOUNT  daily  2021-12-01
# 1        bishop                   IN THE WAITING ROOM  daily  2021-12-02
# 2         yeats                THE DEATH OF CUCHULAIN  daily  2021-12-03
# 3         wilde                                HÉLAS!  daily  2021-12-04
# 4   shakespeare                         SONNET NO. 38  daily  2021-12-05
# 5    chesterton                         THE DEAD HERO  daily  2021-12-06
# 6        bishop                     ARRIVAL AT SANTOS  daily  2021-12-07
# 7     dickinson                          THE BLUE JAY  daily  2021-12-08
# 8        thomas       THE SONG OF THE MISCHIEVOUS DOG  daily  2021-12-09
# 9       ashbery                                ALCOVE  daily  2021-12-10
# 10   chesterton  THE MARCH OF THE BLACK MOUNTAIN 1913  daily  2021-12-11
# 11       kilmer                          DELICATESSEN  daily  2021-12-12
# ...

# %%
history['date'] = [dt.split()[0] for dt in history['date time']]
history['time'] = [dt.split()[1] for dt in history['date time']]
